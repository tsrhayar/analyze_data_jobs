# %% [markdown]
# Based on the provided data, here are some statistics that can be computed:
#
# 1. **Salary Statistics:**
#    - Average Salary: Calculate the average salary for all job positions.
#    - Minimum Salary: Find the minimum salary among all job positions.
#    - Maximum Salary: Find the maximum salary among all job positions.
#    - Salary Distribution: Analyze the distribution of salaries for different job titles.
#
# 2. **Experience Level Distribution:**
#    - Entry-level Percentage: Calculate the percentage of entry-level positions compared to other experience levels.
#
# 3. **Job Type Distribution:**
#    - Full Time vs. Part Time: Determine the distribution of full-time and part-time job types.
#
# 4. **Country-wise Statistics:**
#    - Number of Job Openings: Count the number of job openings in each country.
#    - Average Salary by Country: Calculate the average salary for each country.
#    - Most Common Job Title: Determine the most common job title in each country.
#
# 5. **Company-wise Statistics:**
#    - Number of Job Openings per Company: Count the number of job openings for each company.
#    - Average Salary per Company: Calculate the average salary offered by each company.
#    - Most Common Job Title in Each Company: Determine the most common job title offered by each company.
#
# 6. **Skills and Requirements Analysis:**
#    - Most In-Demand Skills: Identify the most frequently mentioned skills in job requirements.
#    - Skill Frequency: Analyze the frequency of different skills requested by companies.
#
# 7. **Facilities Provided:**
#    - Facilities Analysis: Count the number of job positions offering specific facilities.
#
# Please note that some columns contain special characters and need proper preprocessing to ensure accurate calculations. Additionally, the "Experience level" column contains NaN values, which may need to be handled before performing relevant calculations on it.

# %% [markdown]
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as snsBased on the provided data, here are some statistics that can be computed:
#
# 1. **Salary Statistics:**
#    - Average Salary: Calculate the average salary for all job positions.
#    - Minimum Salary: Find the minimum salary among all job positions.
#    - Maximum Salary: Find the maximum salary among all job positions.
#    - Salary Distribution: Analyze the distribution of salaries for different job titles.
#
# 2. **Experience Level Distribution:**
#    - Entry-level Percentage: Calculate the percentage of entry-level positions compared to other experience levels.
#
# 3. **Job Type Distribution:**
#    - Full Time vs. Part Time: Determine the distribution of full-time and part-time job types.
#
# 4. **Country-wise Statistics:**
#    - Number of Job Openings: Count the number of job openings in each country.
#    - Average Salary by Country: Calculate the average salary for each country.
#    - Most Common Job Title: Determine the most common job title in each country.
#
# 5. **Company-wise Statistics:**
#    - Number of Job Openings per Company: Count the number of job openings for each company.
#    - Average Salary per Company: Calculate the average salary offered by each company.
#    - Most Common Job Title in Each Company: Determine the most common job title offered by each company.
#
# 6. **Skills and Requirements Analysis:**
#    - Most In-Demand Skills: Identify the most frequently mentioned skills in job requirements.
#    - Skill Frequency: Analyze the frequency of different skills requested by companies.
#
# 7. **Facilities Provided:**
#    - Facilities Analysis: Count the number of job positions offering specific facilities.
#
# Please note that some columns contain special characters and need proper preprocessing to ensure accurate calculations. Additionally, the "Experience level" column contains NaN values, which may need to be handled before performing relevant calculations on it.
#
# df = pd.read_csv('./clean_data_with_the_countries2.csv', encoding='ISO-8859-1')
# df = df.rename(columns={"Requirment of the company ": "Requirment of the company"})
#
# df

# %%
average_salary = df['Salary USD'].mean()

# Plot the bar chart
plt.figure(figsize=(12, 6))  # Set the figure size
plt.bar(df['JobTitle'], df['Salary USD'])
plt.axhline(average_salary, color='red', linestyle='dashed', linewidth=2, label='Average Salary')
plt.xlabel('Job Title')
plt.ylabel('Salary USD')
plt.title('Average Salary for Job Titles')
plt.xticks(rotation=70, ha='right')
plt.legend()
plt.tight_layout()
plt.show()

# %%
grouped_data = df.groupby('JobTitle')['Salary USD'].agg(['mean', 'min', 'max']).reset_index()

# Plot the grouped bar chart
plt.figure(figsize=(10, 8))
bar_width = 0.2
index = range(len(grouped_data))

plt.bar(index, grouped_data['mean'], bar_width, label='Average Salary')
plt.bar([i + bar_width for i in index], grouped_data['min'], bar_width, label='Minimum Salary')
plt.bar([i + 2 * bar_width for i in index], grouped_data['max'], bar_width, label='Maximum Salary')

plt.xlabel('Job Title')
plt.ylabel('Salary USD')
plt.title('Salary Statistics for Each Job Title')
plt.xticks([i + bar_width for i in index], grouped_data['JobTitle'], rotation=70, ha='right')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Create a box plot using Seaborn
plt.figure(figsize=(10, 8))
sns.boxplot(x='JobTitle', y='Salary USD', data=df)
plt.title('Salary Distribution for Different Job Titles')
plt.xlabel('Job Title')
plt.ylabel('Salary USD')
plt.xticks(rotation=70, ha='right')

plt.tight_layout()
plt.show()

# %%
# Calculate the entry-level percentage
entry_level_count = df[df['Experience level'] == 'Entry-level'].shape[0]
total_positions = df.shape[0]
entry_level_percentage = (entry_level_count / total_positions) * 100

# Create a pie chart to visualize the distribution
labels = ['Entry-level', 'Other Experience Levels']
sizes = [entry_level_percentage, 100 - entry_level_percentage]
colors = ['#ff9999', '#66b3ff']
explode = (0.1, 0)  # explode the first slice

plt.figure(figsize=(6, 6))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that the pie chart is circular.

plt.title('Entry-level Percentage in Job Positions')
plt.show()

# %%
# Group the data by 'Experience level' and calculate the count for each group
experience_counts = df['Experience level'].value_counts()

# Create a pie chart to visualize the distribution
labels = experience_counts.index
sizes = experience_counts.values
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99']

plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that the pie chart is circular.

plt.title('Percentage of Experience Levels in Job Positions')
plt.show()

# %%
job_type_counts = df['Job Type'].value_counts()

# Create a pie chart to visualize the distribution
labels = job_type_counts.index
sizes = job_type_counts.values
colors = ['#ff9999', '#66b3ff']
explode = (0.1, 0)  # explode the first slice (Full Time)

plt.figure(figsize=(6, 6))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that the pie chart is circular.

plt.title('Distribution of Full Time vs. Part Time Job Types')
plt.show()

# %%
# Count the number of job openings in each country
job_openings_by_country = df['Country'].value_counts()

# Filter the countries where the count is greater than 20
job_openings_greater_than_20 = job_openings_by_country[job_openings_by_country > 20]

# Create a bar chart to visualize the distribution
plt.figure(figsize=(10, 6))
plt.bar(job_openings_greater_than_20.index, job_openings_greater_than_20.values)
plt.xlabel('Country')
plt.ylabel('Number of Job Openings')
plt.title('Number of Job Openings in Each Country (Count > 20)')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %%
filtered_df = df[~df['Country'].str.contains('not found', case=False)]

# Calculate the count of job openings for each country
country_counts = filtered_df['Country'].value_counts()

# Filter the countries with count > 20
filtered_countries = country_counts[country_counts > 10].index

# Filter the DataFrame to keep only the rows for the filtered countries
filtered_df = filtered_df[filtered_df['Country'].isin(filtered_countries)]

# Calculate the average salary for each country
average_salary_by_country = filtered_df.groupby('Country')['Salary USD'].mean().reset_index()

# Sort the DataFrame by average salary in descending order and select the top 25 countries
top_25_countries = average_salary_by_country.nlargest(25, 'Salary USD')

# Create a bar chart to visualize the top 25 countries with the highest average salary
plt.figure(figsize=(12, 6))
plt.bar(top_25_countries['Country'], top_25_countries['Salary USD'])
plt.xlabel('Country')
plt.ylabel('Average Salary USD')
plt.title('Top 25 Countries with Highest Average Salary (Count > 20)')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %%
filtered_df = df[~df['Country'].str.contains('not found', case=False)]

# Calculate the number of job openings per company
job_openings_per_company = filtered_df['Company'].value_counts()

# Filter the companies that have more than 20 job openings
companies_with_more_than_20_jobs = job_openings_per_company[job_openings_per_company > 10]

# Filter the DataFrame to keep only the rows for the companies with more than 20 job openings
filtered_df = filtered_df[filtered_df['Company'].isin(companies_with_more_than_20_jobs.index)]

# Create a bar chart to visualize the number of job openings per company (for companies with more than 20 jobs)
plt.figure(figsize=(10, 6))
plt.bar(companies_with_more_than_20_jobs.index, companies_with_more_than_20_jobs.values)
plt.xlabel('Company')
plt.ylabel('Number of Job Openings')
plt.title('Number of Job Openings per Company')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %%
filtered_df = df[~df['Country'].str.contains('not found', case=False)]

# Calculate the count of job openings per company
job_openings_per_company = filtered_df['Company'].value_counts()

# Filter the companies that have more than 5 job openings
companies_with_more_than_10_jobs = job_openings_per_company[job_openings_per_company > 10].index

# Filter the DataFrame to keep only the rows for the companies with more than 5 job openings
filtered_df = filtered_df[filtered_df['Company'].isin(companies_with_more_than_10_jobs)]

# Calculate the average salary offered by each company
average_salary_per_company = filtered_df.groupby('Company')['Salary USD'].mean().reset_index()

# Sort the DataFrame by average salary in descending order
average_salary_per_company = average_salary_per_company.sort_values(by='Salary USD', ascending=False)

# Create a bar chart to visualize the average salary per company
plt.figure(figsize=(15, 8))
plt.bar(average_salary_per_company['Company'], average_salary_per_company['Salary USD'])
plt.xlabel('Company')
plt.ylabel('Average Salary (USD)')
plt.title('Average Salary per Company (Companies with more than 10 job openings)')
plt.xticks(rotation=90, ha='right')

plt.tight_layout()
plt.show()

# %%
filtered_df = df[~df['Country'].str.contains('not found', case=False)]

# Calculate the count of job openings per company
job_openings_per_company = filtered_df['Company'].value_counts()

# Filter the companies that have more than 5 job openings
companies_with_more_than_10_jobs = job_openings_per_company[job_openings_per_company > 5].index

# Filter the DataFrame to keep only the rows for the companies with more than 5 job openings
filtered_df = filtered_df[filtered_df['Company'].isin(companies_with_more_than_10_jobs)]

# Calculate the average salary offered by each company
average_salary_per_company = filtered_df.groupby('Company')['Salary USD'].mean().reset_index()

# Sort the DataFrame by average salary in descending order
average_salary_per_company = average_salary_per_company.sort_values(by='Salary USD', ascending=False)

# Create a bar chart to visualize the average salary per company
plt.figure(figsize=(15, 8))
plt.bar(average_salary_per_company['Company'], average_salary_per_company['Salary USD'])
plt.xlabel('Company')
plt.ylabel('Average Salary (USD)')
plt.title('Average Salary per Company (Companies with more than 10 job openings)')
plt.xticks(rotation=90, ha='right')

plt.tight_layout()
plt.show()

# %%
filtered_df = df[~df['Country'].str.contains('not found', case=False)]

# Calculate the count of job openings per company
job_openings_per_company = filtered_df['Company'].value_counts()

# Filter the companies that have more than 10 job openings
companies_with_more_than_10_jobs = job_openings_per_company[job_openings_per_company > 10].index

# Filter the DataFrame to keep only the rows for the companies with more than 10 job openings
filtered_df = filtered_df[filtered_df['Company'].isin(companies_with_more_than_10_jobs)]

# Determine the most common job title for each company and their frequency count
most_common_job_titles = filtered_df['JobTitle'].value_counts()

# Create a bar chart to visualize the most common job title in each company
plt.figure(figsize=(10, 6))
most_common_job_titles.plot(kind='bar')
plt.xlabel('Job Title')
plt.ylabel('Frequency Count')
plt.title('Most Common Job Titles in Companies with more than 10 job openings')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %%
filtered_df = df[~df['Country'].str.contains('not found', case=False)]

# Calculate the count of job openings per company
job_openings_per_company = filtered_df['Company'].value_counts()

# Filter the companies that have more than 10 job openings
companies_with_more_than_10_jobs = job_openings_per_company[job_openings_per_company > 10].index

# Filter the DataFrame to keep only the rows for the companies with more than 10 job openings
filtered_df = filtered_df[filtered_df['Company'].isin(companies_with_more_than_10_jobs)]

# Determine the most common job title for each company and their frequency count
most_common_job_titles = filtered_df['JobTitle'].value_counts()

# Sort the most_common_job_titles by frequency count in descending order
most_common_job_titles_sorted = most_common_job_titles.sort_values(ascending=False)

# Create a bar chart to visualize the most common job titles in each company (sorted by frequency count)
plt.figure(figsize=(10, 6))
most_common_job_titles_sorted.plot(kind='bar')
plt.xlabel('Job Title')
plt.ylabel('Frequency Count')
plt.title('Most Common Job Titles in Companies with more than 10 job openings (Sorted)')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()
